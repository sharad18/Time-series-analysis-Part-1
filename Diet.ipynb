# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('diet.csv')
df.set_index('Week', inplace=True)
df.rename(columns={'diet: (Worldwide)': 'diet'}, inplace=True)

# %%
df.head()
# Out:
#             diet
# Week
# 11/9/2014     63
# 11/16/2014    61
# 11/23/2014    53
# 11/30/2014    62
# 12/7/2014     57

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 11/9/2014 to 10/27/2019
# Data columns (total 1 columns):
# diet    260 non-null int64
# dtypes: int64(1)
# memory usage: 4.1+ KB

# %%
df.index = pd.to_datetime(df.index)

# %%
df.plot(grid = True)
plt.show()
